# %% [markdown]
# # 调用本地模型

# %% [markdown]
# ## Ollama

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model='qwen3:8b'
    # base_url='http://localhost:11434'
)

res = model.invoke("介绍一下你自己")
print(res)
# Out:
# content='你好！我是通义千问，由通义实验室研发的超大规模语言模型。我的目标是通过理解和生成自然语言，为用户提供多方面的帮助。以下是我的一些特点和能力：\n\n### 核心功能\n1. **问答与知识理解**  \n   - 可以回答各种领域的问题，从科学常识到文化历史，从技术原理到生活技巧。\n   - 支持多语言交流（中、英、日、韩、法、德、西等），并能理解不同语境下的表达。\n\n2. **创作与表达**  \n   - 能够撰写文章、故事、诗歌、剧本等创意内容。\n   - 支持多种文体风格（正式/轻松/幽默/学术等），可根据需求调整语气和表达方式。\n\n3. **逻辑推理与分析**  \n   - 可辅助解决数学、编程、逻辑谜题等需要推理的问题。\n   - 能对复杂信息进行归纳总结，提炼关键点。\n\n4. **多任务处理**  \n   - 可同时处理多个任务（如翻译、改写、总结、提纲生成等）。\n   - 支持长文本的分段处理和结构化输出。\n\n### 应用场景\n- **学习**：解答学科问题、整理知识点、生成学习资料。\n- **工作**：撰写报告、邮件、合同，或辅助数据分析与决策。\n- **娱乐**：创作故事、角色扮演、生成趣味内容。\n- **生活**：提供建议、解决日常问题（如菜谱、旅行规划等）。\n\n### 技术背景\n- 基于海量文本数据训练，覆盖互联网、书籍、论文等多源信息。\n- 支持实时数据更新（如新闻、天气等），但部分信息可能有延迟。\n- 通过不断优化模型，提升对复杂问题的理解和生成质量。\n\n### 如何与我互动？\n你可以直接提问、描述需求，或提供具体任务。我会尽力提供准确、有用的信息，并根据你的反馈调整回答方式。如果遇到无法解决的问题，我会坦诚说明并提供替代方案。\n\n如果你有任何问题或需要帮助，随时告诉我！ 😊' additional_kwargs={} response_metadata={'model': 'qwen3:8b', 'created_at': '2026-09-16T00:28:46.221925Z', 'done': True, 'done_reason': 'stop', 'total_duration': 29376391334, 'load_duration': 15357625, 'prompt_eval_count': 12, 'prompt_eval_duration': 212673000, 'eval_count': 656, 'eval_duration': 29091983000, 'logprobs': None, 'model_name': 'qwen3:8b', 'model_provider': 'ollama'} id='lc_run--01a0a79d-4441-7ad3-b6cc-e041bd33a577-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 656, 'total_tokens': 668}

# %%
# 举例 2: 使用 init_chat_model()
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model='qwen3:8b',
    model_provider='ollama',
)

res = model.invoke('介绍一下你自己')
print(res)
# Out:
# content='你好！我是通义千问，由通义实验室研发的超大规模语言模型。我的目标是成为你可靠的助手，帮助你完成各种任务，比如：\n\n- **回答问题**：无论是日常疑问还是专业知识，我都能尽力提供准确信息。\n- **创作文字**：写故事、写邮件、写代码注释，甚至创作诗歌，我都能帮你。\n- **逻辑推理**：分析问题、解决数学题、规划方案，我都能协助你思考。\n- **多语言支持**：我懂中文、英文、日语、韩语等多种语言，能与不同语言的用户交流。\n- **编程帮助**：无论是写代码、调试程序，还是解释算法，我都能提供支持。\n\n我可以在日常交流、学习、工作等场景中为你提供帮助。如果你有任何问题或需要协助，随时告诉我！😊' additional_kwargs={} response_metadata={'model': 'qwen3:8b', 'created_at': '2026-09-16T00:29:13.924806Z', 'done': True, 'done_reason': 'stop', 'total_duration': 20920547500, 'load_duration': 3131667, 'prompt_eval_count': 12, 'prompt_eval_duration': 77417000, 'eval_count': 466, 'eval_duration': 20806590000, 'logprobs': None, 'model_name': 'qwen3:8b', 'model_provider': 'ollama'} id='lc_run--01a0a79d-d182-75e2-baa0-96f1a1acb70a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 466, 'total_tokens': 478}
